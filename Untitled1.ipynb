# %%
ti = int(input("insert no one"))
option = input ("what do you choose")
# Out:
#   File "<ipython-input-5-f37b7521e3df>", line 2
#     option = input (+, -, *, /)
#                      ^
# SyntaxError: invalid syntax

# %%
ts = int(input("insert second val"))

# %%
tp = int(input("insert third val"))
# Out:
# insert third val3

# %%
to = int(input("insert fouth val"))
# Out:
# insert fouth val4

# %%
tn = int(input("insert fifty val"))
# Out:
# insert fifty val5

# %%
print(ti + ts - tp * to / tn)
# Out:
# 0.6000000000000001

# %%
num1 = input("Insert you first number")
num2 = input("Insert second number")
num1 = int(num1)
num2 = int(num2)
ULAv= input("If you want to add number then --> + /n 2. If want to subtreact number then --> - /n 3. If want number multiflied then --> * /n 4. If want number divided then --> /")
if ULAv == "+":
  print(num1+num2)
if ULAv == "-":
  print(num1-num2)
if ULAv == "*":
  print(num1*num2)
if ULAv == "/":
  print(round( num1/num2, 2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fc02296c1d04> in <cell line: 1>()
# ----> 1 num1 = input("Insert you first number")
#       2 num2 = input("Insert second number")
#       3 num1 = int(num1)
#       4 num2 = int(num2)
#       5 ULAv= input("If you want to add number then --> + /n 2. If want to subtreact number then --> - /n 3. If want number multiflied then --> * /n 4. If want number divided then --> /")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
num3 = input("Insert 3rd no")
num4 = input("Insert 4th no")
num3 = int(num3)
num4 = int(num4)
UFC= input("To add no --> + /n 2. To sub no --> - /n 3. To mul no --> * /n 4. To div no --> /")
if UFC == "+":
  print(num3+num4)
if UFC == "-":
  print(num3-num4)
if UFC == "*":
  print(num3*num4)
if UFC == "/":
  print(round(num3/num4,4))
# Out:
# Insert 3rd no3
# Insert 4th no4
# To add no --> + /n 2. To sub no --> - /n 3. To mul no --> * /n 4. To div no --> //
# 0.75

# %%
num5 = input("insert fifth number")
num6 = input("insert sixth number")
num5 = int(num5)
num6 = int(num6)
UPS= input("what do you want to do with both the numbers /n 2. To add do + /n 3. To sub do - /n 4. To mul do * /n 5. To div do /")
if UPS == "+":
  result1 = num5+num6
  print(num5+num6)
if UPS == "-":
  result1 = num5-num6
  print(num5-num6)
if UPS == "*":
  result1 = num5*num6
  print(num5*num6)
if UPS == "/":
  result1 = num5/num6
  print(num5/num6)
num7 = input("insert seventh number")
num7 = int(num7)
USP= input("what do you want the third number to do? /n 2. Add + /n 3. Sub - /n 4. Mul * /n 5. Div /")
if USP == "+":
  print(result1+num7)
if USP == "-":
  print(result1-num7)
if USP == "*":
  print(result1*num7)
if USP == "/":
  print(result1/num7)
# Out:
# insert fifth number5
# insert sixth number5
# what do you want to do with both the numbers /n 2. To add do + /n 3. To sub do - /n 4. To mul do * /n 5. To div do //
# 1.0
# insert seventh number5
# what do you want the third number to do? /n 2. Add + /n 3. Sub - /n 4. Mul * /n 5. Div /*
# 5.0
